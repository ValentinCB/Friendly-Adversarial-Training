# %%
cd /content/drive/MyDrive/0_STMI
# Out:
# /content/drive/MyDrive/0_STMI

# %%
! git clone https://github.com/Ohara124c41/Friendly-Adversarial-Training.git
# Out:
# Cloning into 'Friendly-Adversarial-Training'...
# remote: Enumerating objects: 210, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 210 (delta 1), reused 0 (delta 0), pack-reused 204
# Receiving objects: 100% (210/210), 752.89 KiB | 4.09 MiB/s, done.
# Resolving deltas: 100% (86/86), done.

# %%
cd /content/drive/MyDrive/0_STMI/Friendly-Adversarial-Training
# Out:
# /content/drive/MyDrive/0_STMI/Friendly-Adversarial-Training

# %%
# !python /content/drive/MyDrive/0_STMI/Friendly-Adversarial-Training/FAT.py
# Out:
# ==> Load Test Data
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Load Model
# smallcnn
# ==> Friendly Adversarial Training
# Epoch: [1 | 120] | Train Time: 46.00 s | BP Average: 1.51 | Natural Test Acc 0.34 | FGSM Test Acc 0.17 | PGD20 Test Acc 0.12 | CW Test Acc 0.12 |
#
# Epoch: [2 | 120] | Train Time: 50.00 s | BP Average: 2.27 | Natural Test Acc 0.47 | FGSM Test Acc 0.22 | PGD20 Test Acc 0.12 | CW Test Acc 0.14 |
#
# Epoch: [3 | 120] | Train Time: 52.00 s | BP Average: 2.87 | Natural Test Acc 0.54 | FGSM Test Acc 0.26 | PGD20 Test Acc 0.15 | CW Test Acc 0.15 |
#
# Epoch: [4 | 120] | Train Time: 55.00 s | BP Average: 3.23 | Natural Test Acc 0.62 | FGSM Test Acc 0.26 | PGD20 Test Acc 0.11 | CW Test Acc 0.13 |
#
# Epoch: [5 | 120] | Train Time: 55.00 s | BP Average: 3.43 | Natural Test Acc 0.62 | FGSM Test Acc 0.29 | PGD20 Test Acc 0.14 | CW Test Acc 0.16 |
#
# ...

# %%
# !python /content/drive/MyDrive/0_STMI/Friendly-Adversarial-Training/FAT.py --resume='/content/drive/MyDrive/0_STMI/Friendly-Adversarial-Training/FAT_results/checkpoint.pth.tar'
# Out:
# ==> Load Test Data
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Load Model
# smallcnn
# ==> Friendly Adversarial Training Resuming from checkpoint ..
# /content/drive/MyDrive/0_STMI/Friendly-Adversarial-Training/FAT_results/checkpoint.pth.tar
# Epoch: [26 | 120] | Train Time: 79.00 s | BP Average: 5.33 | Natural Test Acc 0.82 | FGSM Test Acc 0.41 | PGD20 Test Acc 0.15 | CW Test Acc 0.16 |
#
# Epoch: [27 | 120] | Train Time: 67.00 s | BP Average: 5.25 | Natural Test Acc 0.83 | FGSM Test Acc 0.39 | PGD20 Test Acc 0.13 | CW Test Acc 0.14 |
#
# Epoch: [28 | 120] | Train Time: 68.00 s | BP Average: 5.48 | Natural Test Acc 0.80 | FGSM Test Acc 0.37 | PGD20 Test Acc 0.14 | CW Test Acc 0.14 |
#
# Epoch: [29 | 120] | Train Time: 67.00 s | BP Average: 5.35 | Natural Test Acc 0.80 | FGSM Test Acc 0.39 | PGD20 Test Acc 0.16 | CW Test Acc 0.16 |
#
# ...
